# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy

import gym
from gym import spaces
from gym.utils import seeding

# %%
class PID:
    def __init__(self, p=5, i=0.1, d=1):
        self.p = p
        self.i = i
        self.d = d
        self.i_value = 0

    def control(self, e, e_d):
        '''
        This function calculates control output
        @params:
            e: angular error
            e_d: angular velocity error
        '''
        self.i_value += e
        self.i_value = np.clip(self.i_value, -10000, 10000)
        return self.p * e + self.i * self.i_value + self.d * e_d

# %% [markdown]
# # linear model

# %%
class Pendulum_PID_Env(gym.Env):
    metadata = {"render.modes": ["human", "rgb_array"], "video.frames_per_second": 30}
    '''
    only PID integrated environment
    '''
    def __init__(self):
        self.M = .5
        self.m = 0.2
        self.F0 = 0.1
        self.F1 = 0.1
        self.I = 0.006
        self.g = 9.8
        self.l = 0.3
        self.dt = 0.01

        high = np.array([np.pi/3, 10, np.pi/3, 10], dtype=np.float32)
        self.action_space = spaces.Box(
            low=np.array([-30], dtype=np.float32), high=np.array([30], dtype=np.float32), shape=(1,), dtype=np.float32
        )
        self.observation_space = spaces.Box(low=-high, high=high, dtype=np.float32)

        self.seed(0)

    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def normalize(self, x):
        return ((x + np.pi) % (2 * np.pi)) - np.pi


    def step(self, PID1_param=[52.49,0,7.485], PID2_param=[129.7,0,11.75], target=[0,0]):
        '''
        @param:
            PID1_param, PID2_param: baseline parameters for 2 PIDs
        '''
        # initialization
        x, x_d, phi, phi_d = self.state  # retrieve info of the actuator link

        M = self.M
        m = self.m
        F0 = self.F0
        F1 = self.F1
        I = self.I
        g = self.g
        l = self.l
        kp1 = PID1_param[0]
        kd1 = PID1_param[2]
        kp2 = PID2_param[0]
        kd2 = PID2_param[2]
        
        p = I*(M+m)+M*m*l**2 # denominator for the A and B matrices
        A = (M+m)*m*g*l/p
        B = -F1*(M+m)/p
        C = F0*m*l/p
        D = -m*l/p
        E = -m*m*g*l*l/p
        F = F1*m*l/p
        G = -F0*(I+m*l*l)/p
        H = (I+m*l*l)/p
        
        
        x_r = 0.5
        e1 = target[0] - phi
        e2 = target[1] - phi_d
        e3 = x_r - x
        e4 = 0 - x_d

        x_d_r = ( kp1*e1+kd1*e2-A*phi-B*phi_d+E*D/H*phi+F*D/H*phi_d+G*D/H*x_d+D/H*kd2*x_d -D/H*kp2*e3) / (C + D/H*kp2*self.dt)
        u = -E/H*phi -F/H*phi_d-G/H*x_d +kp2*self.dt*x_d_r/H + kp2*e3/H  -kd2/H*x_d
        
        
        #### double-loop pd
        # u = kp1*e1+kd1*e2+ kp2*e3+kd2*e4


        # acceleration calculation
        
        phi_dd = A * phi + B * phi_d + C * x_d + D * u
        x_dd = E * phi + F * phi_d + G * x_d + H * u

        # semi-implicit euler
        for _ in range(1):
            x += self.dt * x_d / 1
            x_d += self.dt * x_dd / 1
            x = np.clip(x, -100, 100)
            x_d = np.clip(x_d, -100, 100)

            phi += self.dt * phi_d / 1
            phi_d += self.dt * phi_dd / 1
            phi_d = np.clip(phi_d, -100, 100)
            phi = self.normalize(phi)
        
            
            
        ############## cost ####################
        costs = self.normalize(phi) ** 2 + 0.1 * phi_d**2 # + 1 * ((x-0.5)**2)

        # Output
        self.state = np.array([float(x), float(x_d), float(phi), float(phi_d)])

        return self._get_obs(), -float(costs), False, {'x_d_r':x_d_r, 'u':u}

    def reset(self):
        # always reset all to 0
        high = np.array([np.pi/2, 10, np.pi/2, 10], dtype=np.float32)
        self.state = self.np_random.uniform(low=-high, high=high)
        self.state = np.array([0, 0, 0.5, 0], dtype=np.float32)
        return self.state

    def _get_obs(self):
        # we can only observe the angle of the actuator
        x, x_d, phi, phi_d = self.state
        return np.array([x, x_d, phi, phi_d], dtype=np.float32)

# %% [markdown]
# # testing

# %%
phi_l = []
phi_d_l = []
x_l = []
x_d_l = []
x_d_r_l = []
u_l = []

def episode_run(x1, x2, x3, x4):
    env = Pendulum_PID_Env()
    reward_episode = 0
    

    # Number of steps you run the agent for 
    num_steps = 799
    obs = env.reset()
    
    phi_l.append(obs[2])
    x_l.append(obs[0])
    x_d_r_l.append(0)
    x_d_l.append(obs[1])
    phi_d_l.append(obs[3])
    u_l.append(0)


    ################## simulation
    for step in range(num_steps):

        # apply the action
        obs, reward, done, info = env.step([x1, 0, x2], [x3, 0, x4])

        phi_l.append(obs[2])
        x_l.append(obs[0])
        x_d_r_l.append(info['x_d_r'])
        u_l.append(info['u'])
        x_d_l.append(obs[1])
        phi_d_l.append(obs[3])
        
        reward_episode += reward
        
        
        # If the epsiode is up, then start another one
        if done:
            env.reset()

    # Close the env
    env.close()
    return reward_episode

# %%
# episode_run(240.00, 34.10, 60.00, 79.18) # best proposed
episode_run(-200.0,-39.48,-20.821,-60.76) # best baseline double loop PD
# Out:
# -53.47132256728941

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(phi_l[:800], label='ours') # -7.499676092201453
ax.plot(phi_l[-800:], label='Double-Loop PD') # -7.499676092201453
ax.plot([0]*800, linestyle="-.", label='reference') # -8.540721246923548

plt.title('$x_1$ output of linear model')
plt.xlabel('timestep')
plt.ylabel('rad')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/x1linear.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(phi_d_l[:800], label='ours') # -7.499676092201453
ax.plot(phi_d_l[-800:], label='Double-Loop PD')
ax.plot([0]*800, linestyle="-.", label='reference') # -8.540721246923548

plt.title('$x_2$ output of linear model')
plt.xlabel('timestep')
plt.ylabel('rad/s')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/x2linear.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_l[:800], label='ours') # -7.499676092201453
ax.plot(x_l[-800:], label='Double-Loop PD') # -7.499676092201453
ax.plot([0.5]*800, linestyle="-.", label='reference') # -8.540721246923548

plt.title('$x_3$ output of linear model')
plt.xlabel('timestep')
plt.ylabel('m')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/x3linear.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_d_l[:800], label='ours') # -7.499676092201453
ax.plot(x_d_l[-800:], label='Double-Loop PD') # -7.499676092201453
# ax.plot(x_d_r_l, linestyle="-.", label='reference $x_{4d}$') # -8.540721246923548

plt.title('$x_4$ output of linear model')
plt.xlabel('timestep')
plt.ylabel('m/s')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/x4linear.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(u_l[:800], label='ours') # -7.499676092201453
ax.plot(u_l[-800:], label='Double-Loop PD')

plt.title('$u$ output of linear model')
plt.xlabel('timestep')
plt.ylabel('Nm')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ulinear.png", dpi=500, format="png")

# %% [markdown]
# # BO for linear

# %%
from bayes_opt import BayesianOptimization

# Bounded region of parameter space
pbounds = {'x1': (-200, 200), 'x2': (-100, 100), \
           'x3': (-200, 200), 'x4': (-100, 100)}
optimizer = BayesianOptimization(
    f=episode_run,
    pbounds=pbounds,
    verbose=1, # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
    random_state=2,
)

optimizer.maximize(
    init_points=50,
    n_iter=200,
)
# Out:
# |   iter    |  target   |    x1     |    x2     |    x3     |    x4     |
# -------------------------------------------------------------------------
# |  2        | -8.002e+0 | -31.85    | -33.93    | -118.1    |  23.85    |
# |  4        | -5.686e+0 | -146.2    |  2.716    | -126.2    |  57.07    |
# |  5        | -4.162e+0 |  141.6    | -1.153    |  138.6    | -84.07    |
# |  11       | -1.501e+0 |  185.8    |  0.001672 |  155.8    | -31.68    |
# |  12       | -8.975e+0 |  26.86    | -14.49    | -25.3     |  55.31    |
# |  43       | -7.467e+0 | -29.85    | -11.09    |  3.047    |  5.147    |
# |  50       | -351.5    |  170.4    |  14.05    |  166.7    |  40.45    |
# |  60       | -61.68    |  200.0    |  33.07    |  95.0     |  100.0    |
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ...

# %% [markdown]
# ## Nonlinear (coulomb friction)

# %%
x_dd = 0
cart_fric = 0
pole_fric = 0
class Nonlinear_Pendulum_PID_Env(gym.Env):
    metadata = {"render.modes": ["human", "rgb_array"], "video.frames_per_second": 30}
    '''
    only PID integrated environment
    '''
    def __init__(self):
        self.M = .5
        self.m = 0.2
        self.F0 = 0.1
        self.F1 = 0.1
        self.J = 0.006
        self.g = 9.8
        self.l = 0.3
        self.dt = 0.01

        high = np.array([np.pi/3, 10, np.pi/3, 10], dtype=np.float32)
        self.action_space = spaces.Box(
            low=np.array([-30], dtype=np.float32), high=np.array([30], dtype=np.float32), shape=(1,), dtype=np.float32
        )
        self.observation_space = spaces.Box(low=-high, high=high, dtype=np.float32)

        self.seed(0)

    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def normalize(self, x):
        return ((x + np.pi) % (2 * np.pi)) - np.pi


    def step(self, PID1_param=[52.49,0,7.485], PID2_param=[129.7,0,11.75], target=[0,0]):
        '''
        @param:
            PID1_param, PID2_param: baseline parameters for 2 PIDs
        '''
        # initialization
        x, x_d, phi, phi_d = self.state  # retrieve info of the actuator link

        M = self.M
        m = self.m
        F0 = self.F0
        F1 = self.F1
        J = self.J
        g = self.g
        l = self.l
        dt = self.dt
        
        kp1 = PID1_param[0]
        kd1 = PID1_param[2]
        kp2 = PID2_param[0]
        kd2 = PID2_param[2]
        
        p = (M+m)*(J+m*l**2) - m**2*l**2*np.cos(phi)**2 # denominator for the A and B matrices
        
        
        e1 = target[0] - phi
        e2 = target[1] - phi_d
        x_r = 0.5
        e3 = x_r - x
        e4 = 0 - x_d
        
        x_d_r = p*(kp1*e1+kd1*e2) + F1*(M+m)*phi_d + m*m*l*l*phi_d*phi_d*np.sin(phi)*np.cos(phi) - (M+m)*m*g*l*np.sin(phi) # - F0*m*l*np.cos(phi)*x_d
        x_d_r += m*l*np.cos(phi)/(J+m*l*l) * (-F1*m*l*phi_d*np.cos(phi) -(J+m*l*l)*m*l*phi_d**2*np.sin(phi) \
                                              +F0*(J+m*l*l)*x_d +m*m*g*l*l*np.sin(phi)*np.cos(phi))
        x_d_r += m*l*np.cos(phi)*(p/(J+m*l*l)*(-kd2*x_d+kp2*(x_r-x)))
        x_d_r /= (F0*m*l*np.cos(phi)-p*m*l*np.cos(phi)*kp2*dt/(J+m*l*l))
        
        u = 1/(J+m*l*l) * (-F1*m*l*phi_d*np.cos(phi) -(J+m*l*l)*m*l*phi_d**2*np.sin(phi) \
                           +F0*(J+m*l*l)*x_d +m*m*g*l*l*np.sin(phi)*np.cos(phi))
        u += p/(J+m*l*l) * (kp2*(dt*x_d_r+x_r-x) - kd2*x_d)
        
        # u = kp1*e1+kd1*e2+ kp2*e3+kd2*e4
        
        
        # acceleration calculation
        global x_dd
        global cart_fric
        
        lixin_f = 0.5*m*l*phi_d**2
        # lixin_f = J*phi_d**2
        
        # deduct from u and apply coulomb friction
        if abs(x_d) < 0.0001: # static
            cart_fric = np.sign(x_d)*0.2* max(0, (M+m)*g-lixin_f*np.cos(phi))
            if np.sign(u)*np.sign(u-cart_fric) < 0:
                cart_fric = u
                u = 0
            else:
                u -= cart_fric # friction of the cart directly deducted from u
        else: # moving
            cart_fric = np.sign(x_d)*0.05* ((M+m)*g-lixin_f*np.cos(phi))
            if np.sign(u)*np.sign(u-cart_fric) < 0:
                cart_fric = u
                u = 0
            else:
                u -= cart_fric # friction of the cart directly deducted from u
        
        
        phi_dd = - F1*(M+m)*phi_d - m*m*l*l*phi_d*phi_d*np.sin(phi)*np.cos(phi) + (M+m)*m*g*l*np.sin(phi) + F0*m*l*np.cos(phi)*x_d - m*l*np.cos(phi)*u
        
        phi_dd /= p
        if abs(phi_d)<0.0001:
            pole_fric = (np.sign(phi_d)*0.5 * np.linalg.norm([lixin_f*np.cos(phi),m*x_dd-lixin_f*np.sin(phi)]))*0.01/J # this is angular acceleration
            phi_dd -= (np.sign(phi_d)*0.5 * np.linalg.norm([lixin_f*np.cos(phi),m*x_dd-lixin_f*np.sin(phi)]))*0.01/J # pole friction 0.01 is radius of the bearing
        else:
            pole_fric = (np.sign(phi_d)*0.3 * np.linalg.norm([lixin_f*np.cos(phi),m*x_dd-lixin_f*np.sin(phi)]))*0.01/J # this is angular acceleration
            phi_dd -= (np.sign(phi_d)*0.3 * np.linalg.norm([lixin_f*np.cos(phi),m*x_dd-lixin_f*np.sin(phi)]))*0.01/J # pole friction 0.01 is radius of the bearing
        phi_dd += (np.random.random()-0.5)*1 # random noise
        
        x_dd = F1*m*l*phi_d*np.cos(phi) +(J+m*l*l)*m*l*phi_d**2*np.sin(phi) -F0*(J+m*l*l)*x_d -m*m*g*l*l*np.sin(phi)*np.cos(phi) +(J+m*l*l)*u
        x_dd /= p
        x_dd += (np.random.random()-0.5)*1 # random noise

        # semi-implicit euler
        for _ in range(1):
            x += self.dt * x_d 
            x_d += self.dt * x_dd 
            x = np.clip(x, -100, 100)
            x_d = np.clip(x_d, -100, 100)

            phi += self.dt * phi_d 
            phi_d += self.dt * phi_dd 
            phi_d = np.clip(phi_d, -100, 100)
            phi = self.normalize(phi)
        
            
            
        ############## cost ####################
        costs = self.normalize(phi) ** 2 + 0.1 * phi_d**2 + 2 * e3**2 # + 0.001 * (u**2)

        # Output
        self.state = np.array([float(x), float(x_d), float(phi), float(phi_d)])

        return self._get_obs(), -float(costs), False, {'x_d_r':x_d_r, 'u':u, 'cart_fric': cart_fric/0.01*J, 'pole_fric': pole_fric}

    def reset(self):
        # always reset all to 0
        high = np.array([np.pi/2, 10, np.pi/2, 10], dtype=np.float32)
        self.state = self.np_random.uniform(low=-high, high=high)
        self.state = np.array([0, 0, 0.5, 0], dtype=np.float32)
        return self.state

    def _get_obs(self):
        # we can only observe the angle of the actuator
        x, x_d, phi, phi_d = self.state
        return np.array([x, x_d, phi, phi_d], dtype=np.float32)

# %%
phi_l = []
phi_d_l = []
x_l = []
x_d_l = []
x_d_r_l = []
u_l = []
fric_cart = []
fric_pole = []

def episode_run(x1, x2, x3, x4):
    env = Nonlinear_Pendulum_PID_Env()
    reward_episode = 0
    

    # Number of steps you run the agent for 
    num_steps = 799
    obs = env.reset()
    
    phi_l.append(obs[2])
    x_l.append(obs[0])
    x_d_r_l.append(0)
    x_d_l.append(obs[1])
    phi_d_l.append(obs[3])
    u_l.append(0)


    ################## simulation
    for step in range(num_steps):

        # apply the action
        obs, reward, done, info = env.step([x1, 0, x2], [x3, 0, x4])

        phi_l.append(obs[2])
        x_l.append(obs[0])
        x_d_r_l.append(info['x_d_r'])
        u_l.append(info['u'])
        x_d_l.append(obs[1])
        phi_d_l.append(obs[3])
        fric_cart.append(info['cart_fric'])
        fric_pole.append(info['pole_fric'])
        
        reward_episode += reward
        
        
        # If the epsiode is up, then start another one
        if done:
            env.reset()

    # Close the env
    env.close()
    return reward_episode

# %%
episode_run(240.00, 34.10, 60.00, 79.18) # best proposed
# Out:
# -168.93564912917057

# %%
episode_run(-200.0,-39.48,-20.821,-60.76) # best baseline double loop PD
# Out:
# -147.6266027588158

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(phi_l[:800], label='ours') # -7.499676092201453
ax.plot(phi_l[-800:], label='Double-Loop PD') # -7.499676092201453
ax.plot([0]*800, linestyle="-.", label='reference') # -8.540721246923548

plt.title('$x_1$ output of nonlinear model')
plt.xlabel('timestep')
plt.ylabel('rad')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/x1nonlinear_fri.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(phi_d_l[:800], label='ours') # -7.499676092201453
ax.plot(phi_d_l[-800:], label='Double-Loop PD')
ax.plot([0]*800, linestyle="-.", label='reference') # -8.540721246923548

plt.title('$x_2$ output of nonlinear model')
plt.xlabel('timestep')
plt.ylabel('rad/s')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/x2nonlinear_fri.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_l[:800], label='ours') # -7.499676092201453
ax.plot(x_l[-800:], label='Double-Loop PD') # -7.499676092201453
ax.plot([0.5]*800, linestyle="-.", label='reference') # -8.540721246923548

plt.title('$x_3$ output of nonlinear model')
plt.xlabel('timestep')
plt.ylabel('m')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/x3nonlinear_fri.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_d_l[:800], label='ours') # -7.499676092201453
ax.plot(x_d_l[-800:], label='Double-Loop PD') # -7.499676092201453

plt.title('$x_4$ output of nonlinear model')
plt.xlabel('timestep')
plt.ylabel('m/s')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/x4nonlinear_fri.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(u_l[:800], label='ours') 
ax.plot(u_l[-800:], label='Double-Loop PD')

plt.title('$u$ output of nonlinear model')
plt.xlabel('timestep')
plt.ylabel('Nm')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/unonlinear_fri.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(fric_cart[:800], label='cart friction')
ax.plot(fric_pole[-800:], label='pole friction')

plt.title('coulomb friction of nonlinear model')
plt.xlabel('timestep')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/friction.png", dpi=500, format="png")

# %% [markdown]
# # BO for nonlinear

# %%
from bayes_opt import BayesianOptimization

# Bounded region of parameter space
pbounds = {'x1': (0, 200), 'x2': (0, 100), \
           'x3': (0, 200), 'x4': (0, 100)}
optimizer = BayesianOptimization(
    f=episode_run,
    pbounds=pbounds,
    verbose=1, # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
    random_state=2,
)

optimizer.maximize(
    init_points=50,
    n_iter=100,
)
# Out:
# |   iter    |  target   |    x1     |    x2     |    x3     |    x4     |
# -------------------------------------------------------------------------
# |  2        | -1.028e+0 |  84.07    |  33.03    |  40.93    |  61.93    |
# |  3        | -6.915e+0 |  59.93    |  26.68    |  124.2    |  52.91    |
# |  6        | -6.913e+0 |  101.0    |  6.529    |  85.62    |  9.653    |
# |  12       | -919.8    |  113.4    |  42.75    |  87.35    |  77.66    |
# |  24       | -716.2    |  147.7    |  65.75    |  42.93    |  41.68    |
# |  26       | -168.2    |  155.6    |  13.4     |  173.8    |  74.88    |
# |  49       | -121.7    |  132.4    |  28.33    |  40.17    |  38.83    |
# |  64       | -104.7    |  160.0    |  27.63    |  50.81    |  36.84    |
# |  66       | -98.25    |  113.6    |  16.13    |  46.95    |  24.65    |
# ...

# %% [markdown]
# # ablation study of nonlinear system

# %%
for i in range(5):
    # for ours method
    # episode_run(186.10+4*i, 34.10, 75.00, 88.18) # convergence (as well as oscillation suppression) of phi up, convergence of x down
    # episode_run(196.10, 32.10+4*i, 75.00, 88.18) # contrary to the previous
    # episode_run(196.10, 34.10, 65.00+4*i, 88.18) # covergence of phi down, oscillation down; contratry to x
    # episode_run(196.10, 34.10, 75.00, 78.18+4*i) #  contrary to previous
    
    # for double-loop PD baseline
    # episode_run(-210.1+4*i,-49.48,-30.821,-60.76) # oscillation of x and phi up, 
    # episode_run(-200.1,-59.48+4*i,-30.821,-60.76) # convergence (as well as oscillation suppression) of phi and x up
    # episode_run(-200.1,-49.48,-40.821+4*i,-60.76) # oscillation of phi and x down
    episode_run(-200.1,-49.48,-30.821,-70.76+4*i) #  convergence and oscillation down for phi; oscillation up. convergence up for x

# %% [markdown]
# ## kp1 ours

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(phi_l[0*800:1*800], label='$k_{p1}=186.10$')
ax.plot(phi_l[1*800:2*800], label='$k_{p1}=190.10$')
ax.plot(phi_l[2*800:3*800], label='$k_{p1}=194.10$')
ax.plot(phi_l[3*800:4*800], label='$k_{p1}=198.10$')
ax.plot(phi_l[4*800:5*800], label='$k_{p1}=202.10$')


plt.title('Ablation Study, $k_{d1}=34.10,k_{p2}=75.00,k_{d2}=88.18$')
plt.xlabel('timestep')
plt.ylabel('rad')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_ours_kp1_phi.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_l[0*800:1*800], label='$k_{p1}=186.10$')
ax.plot(x_l[1*800:2*800], label='$k_{p1}=190.10$')
ax.plot(x_l[2*800:3*800], label='$k_{p1}=194.10$')
ax.plot(x_l[3*800:4*800], label='$k_{p1}=198.10$')
ax.plot(x_l[4*800:5*800], label='$k_{p1}=202.10$')


plt.title('Ablation Study, $k_{d1}=34.10,k_{p2}=75.00,k_{d2}=88.18$')
plt.xlabel('timestep')
plt.ylabel('m')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_ours_kp1_x.png", dpi=500, format="png")

# %% [markdown]
# ## kp2 ours

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(phi_l[0*800:1*800], label='$k_{p2}=65.00$')
ax.plot(phi_l[1*800:2*800], label='$k_{p2}=69.00$')
ax.plot(phi_l[2*800:3*800], label='$k_{p2}=73.00$')
ax.plot(phi_l[3*800:4*800], label='$k_{p2}=77.00$')
ax.plot(phi_l[4*800:5*800], label='$k_{p2}=81.00$')


plt.title('Ablation Study, $k_{p1}=196.10,k_{d1}=34.10,k_{d2}=88.18$')
plt.xlabel('timestep')
plt.ylabel('rad')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_ours_kp2_phi.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_l[0*800:1*800], label='$k_{p2}=65.00$')
ax.plot(x_l[1*800:2*800], label='$k_{p2}=69.00$')
ax.plot(x_l[2*800:3*800], label='$k_{p2}=73.00$')
ax.plot(x_l[3*800:4*800], label='$k_{p2}=77.00$')
ax.plot(x_l[4*800:5*800], label='$k_{p2}=81.00$')


plt.title('Ablation Study, $k_{p1}=196.10,k_{d1}=34.10,k_{d2}=88.18$')
plt.xlabel('timestep')
plt.ylabel('m')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_ours_kp2_x.png", dpi=500, format="png")

# %% [markdown]
# ## kd1 ours

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(phi_l[0*800:1*800], label='$k_{d1}=32.10$')
ax.plot(phi_l[1*800:2*800], label='$k_{d1}=36.10$')
ax.plot(phi_l[2*800:3*800], label='$k_{d1}=40.10$')
ax.plot(phi_l[3*800:4*800], label='$k_{d1}=44.10$')
ax.plot(phi_l[4*800:5*800], label='$k_{d1}=48.10$')


plt.title('Ablation Study, $k_{p1}=196.10,k_{p2}=75.00,k_{d2}=88.18$')
plt.xlabel('timestep')
plt.ylabel('rad')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_ours_kd1_phi.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_l[0*800:1*800], label='$k_{d1}=32.10$')
ax.plot(x_l[1*800:2*800], label='$k_{d1}=36.10$')
ax.plot(x_l[2*800:3*800], label='$k_{d1}=40.10$')
ax.plot(x_l[3*800:4*800], label='$k_{d1}=44.10$')
ax.plot(x_l[4*800:5*800], label='$k_{d1}=48.10$')


plt.title('Ablation Study, $k_{p1}=196.10,k_{p2}=75.00,k_{d2}=88.18$')
plt.xlabel('timestep')
plt.ylabel('m')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_ours_kd1_x.png", dpi=500, format="png")

# %% [markdown]
# ## kd2 ours

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(phi_l[0*800:1*800], label='$k_{d2}=78.18$')
ax.plot(phi_l[1*800:2*800], label='$k_{d2}=82.18$')
ax.plot(phi_l[2*800:3*800], label='$k_{d2}=86.18$')
ax.plot(phi_l[3*800:4*800], label='$k_{d2}=90.18$')
ax.plot(phi_l[4*800:5*800], label='$k_{d2}=94.18$')

plt.title('Ablation Study, $k_{p1}=196.10,k_{p2}=75.00,k_{d1}=34.10$')
plt.xlabel('timestep')
plt.ylabel('rad')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_ours_kd2_phi.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_l[0*800:1*800], label='$k_{d2}=78.18$')
ax.plot(x_l[1*800:2*800], label='$k_{d2}=82.18$')
ax.plot(x_l[2*800:3*800], label='$k_{d2}=86.18$')
ax.plot(x_l[3*800:4*800], label='$k_{d2}=90.18$')
ax.plot(x_l[4*800:5*800], label='$k_{d2}=94.18$')

plt.title('Ablation Study, $k_{p1}=196.10,k_{p2}=75.00,k_{d1}=34.10$')
plt.xlabel('timestep')
plt.ylabel('m')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_ours_kd2_x.png", dpi=500, format="png")

# %% [markdown]
# ## kp1 baseline

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(phi_l[0*800:1*800], label='$k_{p1}=210.10$')
ax.plot(phi_l[1*800:2*800], label='$k_{p1}=206.10$')
ax.plot(phi_l[2*800:3*800], label='$k_{p1}=202.10$')
ax.plot(phi_l[3*800:4*800], label='$k_{p1}=198.10$')
ax.plot(phi_l[4*800:5*800], label='$k_{p1}=194.10$')


plt.title('Ablation Study, $k_{d1}=49.48,k_{p2}=30.82,k_{d2}=50.76$')
plt.xlabel('timestep')
plt.ylabel('rad')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_baseline_kp1_phi.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_l[0*800:1*800], label='$k_{p1}=210.10$')
ax.plot(x_l[1*800:2*800], label='$k_{p1}=206.10$')
ax.plot(x_l[2*800:3*800], label='$k_{p1}=202.10$')
ax.plot(x_l[3*800:4*800], label='$k_{p1}=198.10$')
ax.plot(x_l[4*800:5*800], label='$k_{p1}=194.10$')


plt.title('Ablation Study, $k_{d1}=49.48,k_{p2}=30.82,k_{d2}=50.76$')
plt.xlabel('timestep')
plt.ylabel('m')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_baseline_kp1_x.png", dpi=500, format="png")

# %% [markdown]
# ## kp2 baseline

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(phi_l[0*800:1*800], label='$k_{p2}=40.82$')
ax.plot(phi_l[1*800:2*800], label='$k_{p2}=36.82$')
ax.plot(phi_l[2*800:3*800], label='$k_{p2}=32.82$')
ax.plot(phi_l[3*800:4*800], label='$k_{p2}=28.82$')
ax.plot(phi_l[4*800:5*800], label='$k_{p2}=24.82$')


plt.title('Ablation Study, $k_{p1}=200.10,k_{d1}=49.48,k_{d2}=50.76$')
plt.xlabel('timestep')
plt.ylabel('rad')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_baseline_kp2_phi.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_l[0*800:1*800], label='$k_{p2}=40.82$')
ax.plot(x_l[1*800:2*800], label='$k_{p2}=36.82$')
ax.plot(x_l[2*800:3*800], label='$k_{p2}=32.82$')
ax.plot(x_l[3*800:4*800], label='$k_{p2}=28.82$')
ax.plot(x_l[4*800:5*800], label='$k_{p2}=24.82$')


plt.title('Ablation Study, $k_{p1}=200.10,k_{d1}=49.48,k_{d2}=50.76$')
plt.xlabel('timestep')
plt.ylabel('m')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_baseline_kp2_x.png", dpi=500, format="png")

# %% [markdown]
# ## kd1 baseline

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(phi_l[0*800:1*800], label='$k_{d1}=59.48$')
ax.plot(phi_l[1*800:2*800], label='$k_{d1}=55.48$')
ax.plot(phi_l[2*800:3*800], label='$k_{d1}=51.48$')
ax.plot(phi_l[3*800:4*800], label='$k_{d1}=47.48$')
ax.plot(phi_l[4*800:5*800], label='$k_{d1}=43.48$')


plt.title('Ablation Study, $k_{p1}=200.10,k_{p2}=30.82,k_{d2}=50.76$')
plt.xlabel('timestep')
plt.ylabel('rad')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_baseline_kd1_phi.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_l[0*800:1*800], label='$k_{d1}=59.48$')
ax.plot(x_l[1*800:2*800], label='$k_{d1}=55.48$')
ax.plot(x_l[2*800:3*800], label='$k_{d1}=51.48$')
ax.plot(x_l[3*800:4*800], label='$k_{d1}=47.48$')
ax.plot(x_l[4*800:5*800], label='$k_{d1}=43.48$')


plt.title('Ablation Study, $k_{p1}=200.10,k_{p2}=30.82,k_{d2}=50.76$')
plt.xlabel('timestep')
plt.ylabel('m')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_baseline_kd1_x.png", dpi=500, format="png")

# %% [markdown]
# ## kd2 baseline

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(phi_l[0*800:1*800], label='$k_{d2}=70.76$')
ax.plot(phi_l[1*800:2*800], label='$k_{d2}=66.76$')
ax.plot(phi_l[2*800:3*800], label='$k_{d2}=62.76$')
ax.plot(phi_l[3*800:4*800], label='$k_{d2}=58.76$')
ax.plot(phi_l[4*800:5*800], label='$k_{d2}=54.76$')


plt.title('Ablation Study, $k_{p1}=200.10,k_{p2}=30.82,k_{d1}=49.48$')
plt.xlabel('timestep')
plt.ylabel('rad')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_baseline_kd2_phi.png", dpi=500, format="png")

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_l[0*800:1*800], label='$k_{d2}=70.76$')
ax.plot(x_l[1*800:2*800], label='$k_{d2}=66.76$')
ax.plot(x_l[2*800:3*800], label='$k_{d2}=62.76$')
ax.plot(x_l[3*800:4*800], label='$k_{d2}=58.76$')
ax.plot(x_l[4*800:5*800], label='$k_{d2}=54.76$')


plt.title('Ablation Study, $k_{p1}=200.10,k_{p2}=30.82,k_{d1}=49.48$')
plt.xlabel('timestep')
plt.ylabel('m')
plt.legend()
fig.savefig("C:/Users/Lenovo/Desktop/figures/ablation_baseline_kd2_x.png", dpi=500, format="png")
